# %% [markdown]
# <a href="https://colab.research.google.com/github/IG0RPN/PythonGrafico/blob/main/biPYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
lista_arquivos = os.listdir("/content/drive/MyDrive/py bi/Vendas/Vendas")
display(lista_arquivos)
# Out:
# ['Devolucoes - Belo Horizonte.csv',
#  'Vendas - São Paulo.csv',
#  'Devolucoes - Curitiba.csv',
#  'Devolucoes - Salvador.csv',
#  'Vendas - Salvador.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Vendas - Curitiba.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Vendas - Recife.csv',
#  'Devolucoes - Goiás.csv',
#  'Vendas - Porto Alegre.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - São Paulo.csv',
#  'Vendas - Fortaleza.csv']

# %%
for arquivo in lista_arquivos: 
    print (f"/content/drive/MyDrive/py bi/Vendas/Vendas/{arquivo}")
# Out:
# /content/drive/MyDrive/py bi/Vendas/Vendas/Devolucoes - Belo Horizonte.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Vendas - São Paulo.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Devolucoes - Curitiba.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Devolucoes - Salvador.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Vendas - Salvador.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Vendas - Belo Horizonte.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Devolucoes - Fortaleza.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Devolucoes - Rio de Janeiro.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Vendas - Goiás.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Vendas - Rio de Janeiro.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Vendas - Curitiba.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Devolucoes - Porto Alegre.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Vendas - Recife.csv
# /content/drive/MyDrive/py bi/Vendas/Vendas/Devolucoes - Goiás.csv
# ...

# %%
for arquivo in lista_arquivos:
  if "Vendas" in arquivo:
    print (f"/content/drive/MyDrive/py bi/Vendas/Vendas/{arquivo}")
    
    tabela = pd.read_csv(f"/content/drive/MyDrive/py bi/Vendas/Vendas/{arquivo}")
    display(tabela)
# Out:
# /content/drive/MyDrive/py bi/Vendas/Vendas/Vendas - São Paulo.csv
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0              5  HL1918      iPhone                   4         Sarah
# 1              6  HL7348  SmartWatch                   3     Alexandre
# 2              9  HL1148      Câmera                   3       Camille
# 3             10  HL1918      iPhone                   3          Alon
# 4             18  HL8851    Notebook                   4       Leandro
# ...          ...     ...         ...                 ...           ...
# 2221        9981  HL7348  SmartWatch                   4          João
# 2222        9984  HL1918      iPhone                   4          Itai
# 2223        9985  HL1918      iPhone                   1     Guilherme
# 2224        9991  HL7348  SmartWatch                   5       Antônio
# 2225        9996  HL4379   Televisão                   5          Caio
#
# ...

# %%
for arquivo in lista_arquivos:
  if "Vendas" in arquivo:

    tabela = pd.read_csv(f"/content/drive/MyDrive/py bi/Vendas/Vendas/{arquivo}")
    print(arquivo)
    display(tabela)
# Out:
# Vendas - São Paulo.csv
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0              5  HL1918      iPhone                   4         Sarah
# 1              6  HL7348  SmartWatch                   3     Alexandre
# 2              9  HL1148      Câmera                   3       Camille
# 3             10  HL1918      iPhone                   3          Alon
# 4             18  HL8851    Notebook                   4       Leandro
# ...          ...     ...         ...                 ...           ...
# 2221        9981  HL7348  SmartWatch                   4          João
# 2222        9984  HL1918      iPhone                   4          Itai
# 2223        9985  HL1918      iPhone                   1     Guilherme
# 2224        9991  HL7348  SmartWatch                   5       Antônio
# 2225        9996  HL4379   Televisão                   5          Caio
#
#       Sobrenome        Data       Loja  Preco Unitario  Unnamed: 8
# ...

# %%
tabela_total = pd.DataFrame()

for arquivo in lista_arquivos:
  if "Vendas" in arquivo:

    tabela = pd.read_csv(f"/content/drive/MyDrive/py bi/Vendas/Vendas/{arquivo}")
    tabela_total = tabela_total.append(tabela)
display(tabela_total)
# Out:
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0              5  HL1918      iPhone                   4         Sarah
# 1              6  HL7348  SmartWatch                   3     Alexandre
# 2              9  HL1148      Câmera                   3       Camille
# 3             10  HL1918      iPhone                   3          Alon
# 4             18  HL8851    Notebook                   4       Leandro
# ...          ...     ...         ...                 ...           ...
# 1442        9959  HL1918      iPhone                   4        Rafael
# 1443        9974  HL1148      Câmera                   2        Thales
# 1444        9979  HL1918      iPhone                   5        Brenno
# 1445        9994  HL4379   Televisão                   2          Caio
# 1446        9995  HL1148      Câmera                   5           Kim
#
#       Sobrenome        Data       Loja  Preco Unitario  Unnamed: 8
# ...

# %%
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida"]].sort_values(by="Quantidade Vendida", ascending=False)
display(tabela_produtos)
# Out:
#             Quantidade Vendida
# Produto
# iPhone                    8974
# Televisão                 5931
# Notebook                  3249
# Android                   3183
# SmartWatch                2980
# Tablet                    2921
# Câmera                    2805

# %%
for arquivo in lista_arquivos:
  if "Vendas" in arquivo:

    tabela = pd.read_csv(f"/content/drive/MyDrive/py bi/Vendas/Vendas/{arquivo}")
    tabela_total = tabela_total.append(tabela)
display(tabela_total)
# Out:
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0              5  HL1918      iPhone                   4         Sarah
# 1              6  HL7348  SmartWatch                   3     Alexandre
# 2              9  HL1148      Câmera                   3       Camille
# 3             10  HL1918      iPhone                   3          Alon
# 4             18  HL8851    Notebook                   4       Leandro
# ...          ...     ...         ...                 ...           ...
# 1442        9959  HL1918      iPhone                   4        Rafael
# 1443        9974  HL1148      Câmera                   2        Thales
# 1444        9979  HL1918      iPhone                   5        Brenno
# 1445        9994  HL4379   Televisão                   2          Caio
# 1446        9995  HL1148      Câmera                   5           Kim
#
#       Sobrenome        Data       Loja  Preco Unitario  Unnamed: 8
# ...

# %%
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']
tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending=False)

display(tabela_faturamento)
# Out:
#             Faturamento
# Produto
# iPhone         95124400
# Televisão      29655000
# Notebook       22743000
# Android        21644400
# Câmera         11781000
# Tablet          9347200
# SmartWatch      8344000

# %%
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']]
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# Belo Horizonte     12960600
# Curitiba           14121000
# Fortaleza          28175800
# Goiás              14883600
# Porto Alegre       13737200
# Recife             14606000
# Rio de Janeiro     29735600
# Salvador           26222600
# São Paulo          44196600

# %%
import plotly.express as px 

grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y='Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
